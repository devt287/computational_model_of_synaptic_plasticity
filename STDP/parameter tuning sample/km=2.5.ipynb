# %%
import importlib
import state_analysis
from state_analysis import *

# %%
importlib.reload(state_analysis)
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# %%
k14_8=import_data("data/km=2.5_k14=8_k4=18_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
k14_8_5=import_data("data/km=2.5_k14=8.5_k4=18_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
k14_9=import_data("data/km=2.5_k14=9_k4=18_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
k14_10=import_data("data/km=2.5_k14=10_k4=18_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
export_data(k14_8,"data/km=2.5_k14=8_k4=18_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
export_data(k14_8_5,"data/km=2.5_k14=8.5_k4=18_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
export_data(k14_9,"data/km=2.5_k14=9_k4=18_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
export_data(k14_10,"data/km=2.5_k14=10_k4=18_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")

# %%
k14_8_info=get_info(k14_8)
k14_8_5_info=get_info(k14_8_5)
k14_9_info=get_info(k14_9)
k14_10_info=get_info(k14_10)

# %%
info_list=[k14_8_info,k14_8_5_info,k14_9_info,k14_10_info]
name_list=["k14=8","k14=8.5","k14=9","k14=10"]
visualize_multiple_list_groups(name_list,info_list,"k14")
