# %%
import importlib
import state_analysis
from state_analysis import *

# %%
importlib.reload(state_analysis)
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# %%
k4_8=import_data("data/km=3_k14=8_k4=19_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
k4_9=import_data("data/km=3_k14=9_k4=19_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
k4_10=import_data("data/km=3_k14=10_k4=19_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
k4_12=import_data("data/km=3_k14=12_k4=19_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
export_data(k4_8, "data/km=3_k14=8_k4=19_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
export_data(k4_9, "data/km=3_k14=9_k4=19_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
export_data(k4_10, "data/km=3_k14=10_k4=19_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")
export_data(k4_12, "data/km=3_k14=12_k4=19_a=0.3_Km12=0.9_Km=3_K14=2_k11=0.055_1.3_new.txt")

# %%
k4_8_info = get_info(k4_8)
k4_9_info = get_info(k4_9)
k4_10_info = get_info(k4_10)
k4_12_info = get_info(k4_12)

# %%
info_list = [k4_8_info, k4_9_info, k4_10_info, k4_12_info]
name_list = ["k14=8", "k14=9", "k14=10", "k14=12"]
visualize_multiple_list_groups(name_list,info_list,"k4")
