# %%
import importlib
import state_analysis
from state_analysis import *

# %%
importlib.reload(state_analysis)
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# %%
b_25 = import_data("data/fix_a=0.25/a=0.25_b=0.3_hpc.txt")
b_40 = import_data("data/fix_a=0.25/a=0.25_b=0.4_hpc.txt")
b_45 = import_data("data/fix_a=0.25/a=0.25_b=0.45_hpc.txt")
b_50 = import_data("data/fix_a=0.25/a=0.25_b=0.5_hpc.txt")
b_55 = import_data("data/fix_a=0.25/a=0.25_b=0.55_hpc.txt")
b_60 = import_data("data/fix_a=0.25/a=0.25_b=0.6_hpc.txt")
b_65 = import_data("data/fix_a=0.25/a=0.25_b=0.65_hpc.txt")
b_70 = import_data("data/fix_a=0.25/a=0.25_b=0.7_hpc.txt")
b_75 = import_data("data/fix_a=0.25/a=0.25_b=0.75_hpc.txt")
b_80 = import_data("data/fix_a=0.25/a=0.25_b=0.8_hpc.txt")
export_data(b_25, "data/fix_a=0.25/a=0.25_b=0.3_hpc.txt")
export_data(b_40, "data/fix_a=0.25/a=0.25_b=0.4_hpc.txt")
export_data(b_45, "data/fix_a=0.25/a=0.25_b=0.45_hpc.txt")
export_data(b_50, "data/fix_a=0.25/a=0.25_b=0.5_hpc.txt")
export_data(b_55, "data/fix_a=0.25/a=0.25_b=0.55_hpc.txt")
export_data(b_60, "data/fix_a=0.25/a=0.25_b=0.6_hpc.txt")
export_data(b_65, "data/fix_a=0.25/a=0.25_b=0.65_hpc.txt")
export_data(b_70, "data/fix_a=0.25/a=0.25_b=0.7_hpc.txt")
export_data(b_75, "data/fix_a=0.25/a=0.25_b=0.75_hpc.txt")
export_data(b_80, "data/fix_a=0.25/a=0.25_b=0.8_hpc.txt")

# %%
b_25_info = get_info(b_25)
b_40_info = get_info(b_40)
b_45_info = get_info(b_45)
b_50_info = get_info(b_50)
b_55_info = get_info(b_55)
b_60_info = get_info(b_60)
b_65_info = get_info(b_65)
b_70_info = get_info(b_70)
b_75_info = get_info(b_75)
b_80_info = get_info(b_80)

# %%
info_list=[b_25_info, b_40_info, b_45_info, b_50_info, b_55_info, b_60_info, b_65_info, b_70_info, b_75_info, b_80_info]
name_list=[0.25, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8]
state_list = [b_25, b_40, b_45, b_50, b_55, b_60, b_65, b_70, b_75, b_80]
visualize_multiple_list_groups(name_list,info_list,"km12")

# %%
DPD_combo(state_list,info_list,"/Users/dtwm/Documents/MATLAB/synaptic plasticity/project1/11.24/a=0.25, km12 effect/"
)
# Out:
# Saved heatmap to /Users/dtwm/Documents/MATLAB/synaptic plasticity/project1/11.24/a=0.25, km12 effect/heatmap_1.png
# Saved heatmap to /Users/dtwm/Documents/MATLAB/synaptic plasticity/project1/11.24/a=0.25, km12 effect/heatmap_2.png
# Saved heatmap to /Users/dtwm/Documents/MATLAB/synaptic plasticity/project1/11.24/a=0.25, km12 effect/heatmap_3.png
# Saved heatmap to /Users/dtwm/Documents/MATLAB/synaptic plasticity/project1/11.24/a=0.25, km12 effect/heatmap_4.png
# Saved heatmap to /Users/dtwm/Documents/MATLAB/synaptic plasticity/project1/11.24/a=0.25, km12 effect/heatmap_5.png
# Saved heatmap to /Users/dtwm/Documents/MATLAB/synaptic plasticity/project1/11.24/a=0.25, km12 effect/heatmap_6.png
# Saved heatmap to /Users/dtwm/Documents/MATLAB/synaptic plasticity/project1/11.24/a=0.25, km12 effect/heatmap_7.png
# Saved heatmap to /Users/dtwm/Documents/MATLAB/synaptic plasticity/project1/11.24/a=0.25, km12 effect/heatmap_8.png
# ...
